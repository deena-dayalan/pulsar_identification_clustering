# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import skew
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
## dataset file
pulsar_dataset = '/home/d.dasarathan/ds5500/projects/datasets/HTRU2/HTRU_2.csv'

# %%
## read dataset
df_main = pd.read_csv(pulsar_dataset, header=None)

# %%
## display sample dataset
df_main.head()
# Out:
#             0          1         2         3         4          5          6  \
# 0  140.562500  55.683782 -0.234571 -0.699648  3.199833  19.110426   7.975532
# 1  102.507812  58.882430  0.465318 -0.515088  1.677258  14.860146  10.576487
# 2  103.015625  39.341649  0.323328  1.051164  3.121237  21.744669   7.735822
# 3  136.750000  57.178449 -0.068415 -0.636238  3.642977  20.959280   6.896499
# 4   88.726562  40.672225  0.600866  1.123492  1.178930  11.468720  14.269573
#
#             7  8
# 0   74.242225  0
# 1  127.393580  0
# 2   63.171909  0
# 3   53.593661  0
# 4  252.567306  0

# %% [markdown]
# ### Column names
# 1. Mean of the integrated profile (mean_int_pf).
# 2. Standard deviation of the integrated profile (std_pf).
# 3. Excess kurtosis of the integrated profile (ex_kurt_pf).
# 4. Skewness of the integrated profile (skew_pf).
# 5. Mean of the DM-SNR curve (mean_dm).
# 6. Standard deviation of the DM-SNR curve (std_dm).
# 7. Excess kurtosis of the DM-SNR curve (kurt_dm).
# 8. Skewness of the DM-SNR curve (skew_dm).
# 9. Label ( For real pulsars, the class label is 1; otherwise, the class label is 0)

# %%
## add column names to dataset
col_names = ['mean_int_pf', 'std_pf', 'ex_kurt_pf', 'skew_pf', 'mean_dm', 'std_dm', 'kurt_dm', 'skew_dm','label']
df_main.columns = col_names
df_main.head()
# Out:
#    mean_int_pf     std_pf  ex_kurt_pf   skew_pf   mean_dm     std_dm  \
# 0   140.562500  55.683782   -0.234571 -0.699648  3.199833  19.110426
# 1   102.507812  58.882430    0.465318 -0.515088  1.677258  14.860146
# 2   103.015625  39.341649    0.323328  1.051164  3.121237  21.744669
# 3   136.750000  57.178449   -0.068415 -0.636238  3.642977  20.959280
# 4    88.726562  40.672225    0.600866  1.123492  1.178930  11.468720
#
#      kurt_dm     skew_dm  label
# 0   7.975532   74.242225      0
# 1  10.576487  127.393580      0
# 2   7.735822   63.171909      0
# 3   6.896499   53.593661      0
# 4  14.269573  252.567306      0

# %%
df_main.iloc[: , :-1].describe()
# Out:
#         mean_int_pf        std_pf    ex_kurt_pf       skew_pf       mean_dm  \
# count  17898.000000  17898.000000  17898.000000  17898.000000  17898.000000
# mean     111.079968     46.549532      0.477857      1.770279     12.614400
# std       25.652935      6.843189      1.064040      6.167913     29.472897
# min        5.812500     24.772042     -1.876011     -1.791886      0.213211
# 25%      100.929688     42.376018      0.027098     -0.188572      1.923077
# 50%      115.078125     46.947479      0.223240      0.198710      2.801839
# 75%      127.085938     51.023202      0.473325      0.927783      5.464256
# max      192.617188     98.778911      8.069522     68.101622    223.392141
#
#              std_dm       kurt_dm       skew_dm
# count  17898.000000  17898.000000  17898.000000
# mean      26.326515      8.303556    104.857709
# std       19.470572      4.506092    106.514540
# min        7.370432     -3.139270     -1.976976
# ...

# %%
# view summary of dataset
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mean_int_pf  17898 non-null  float64
#  1   std_pf       17898 non-null  float64
#  2   ex_kurt_pf   17898 non-null  float64
#  3   skew_pf      17898 non-null  float64
#  4   mean_dm      17898 non-null  float64
#  5   std_dm       17898 non-null  float64
#  6   kurt_dm      17898 non-null  float64
#  7   skew_dm      17898 non-null  float64
#  8   label        17898 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %%
df_main.label.value_counts()
# Out:
# 0    16259
# 1     1639
# Name: label, dtype: int64

# %%
df_main['label'].value_counts()/np.float(len(df_main)) * 100
# Out:
# 0    90.842552
# 1     9.157448
# Name: label, dtype: float64

# %%
## check for none in dataset
df_main.isna().sum()
# Out:
# mean_int_pf    0
# std_pf         0
# ex_kurt_pf     0
# skew_pf        0
# mean_dm        0
# std_dm         0
# kurt_dm        0
# skew_dm        0
# label          0
# dtype: int64

# %%
## check for null in dataset
df_main.isnull().sum()
# Out:
# mean_int_pf    0
# std_pf         0
# ex_kurt_pf     0
# skew_pf        0
# mean_dm        0
# std_dm         0
# kurt_dm        0
# skew_dm        0
# label          0
# dtype: int64

# %%
df_main.dtypes
# Out:
# mean_int_pf    float64
# std_pf         float64
# ex_kurt_pf     float64
# skew_pf        float64
# mean_dm        float64
# std_dm         float64
# kurt_dm        float64
# skew_dm        float64
# label            int64
# dtype: object

# %%
## plot class label bar chart
objects = ('RFI', 'Pulsar')
sns.set(rc = {'figure.figsize':(8,6)})
sns.set_style("whitegrid")
ax = sns.countplot(x="label", data=df_main)
ax.set_xlabel("Class label")
ax.set_ylabel("Number of samples")
ax.set_title("Check for class imbalance", fontsize=10)

patches = [Patch(color=sns.color_palette()[i], label=t) for i,t in enumerate(t.get_text() for t in ax.get_xticklabels())]

plt.legend(title='Target', labels=objects, handles=patches, loc="upper right")
plt.savefig("../visuals/class_imbalance.png")
plt.show()

# %%
## Skewness of each feature
for col in df_main.iloc[: , :-1]:
    print(col+" : "+str(skew(df_main[col])))
# Out:
# mean_int_pf : -1.3750723905207278
# std_pf : 0.1266304634037971
# ex_kurt_pf : 3.6381047281725745
# skew_pf : 5.180859198774812
# mean_dm : 3.6829934238565114
# std_dm : 1.894095372422393
# kurt_dm : 0.4414638629012641
# skew_dm : 2.734284379273907

# %%
# plot histogram to check distribution

plt_fig = plt.figure(figsize=(18,15))

fig = plt_fig.add_subplot(3, 3, 1)
fig = df_main.mean_int_pf.hist(bins=50)
fig.set_xlabel('mean_int_pf')
fig.set_ylabel('count')


plt.subplot(3, 3, 2)
fig = df_main.std_pf.hist(bins=50)
fig.set_xlabel('std_pf')
fig.set_ylabel('count')

plt.subplot(3, 3, 3)
fig = df_main.ex_kurt_pf.hist(bins=50)
fig.set_xlabel('ex_kurt_pf')
fig.set_ylabel('count')

plt.subplot(3, 3, 4)
fig = df_main.skew_pf.hist(bins=50)
fig.set_xlabel('skew_pf')
fig.set_ylabel('count')

plt.subplot(3, 3, 5)
fig = df_main.mean_dm.hist(bins=50)
fig.set_xlabel('mean_dm')
fig.set_ylabel('count')

plt.subplot(3, 3, 6)
fig = df_main.std_dm.hist(bins=50)
fig.set_xlabel('std_dm')
fig.set_ylabel('count')

plt.subplot(3, 3, 7)
fig = df_main.kurt_dm.hist(bins=50)
fig.set_xlabel('kurt_dm')
fig.set_ylabel('count')

plt.subplot(3, 3, 8)
fig = df_main.skew_dm.hist(bins=50)
fig.set_xlabel('skew_dm')
fig.set_ylabel('count')

plt.show()
plt.savefig("../visuals/histograms.png")

# %%
## Correlation matrix
sns.heatmap(df_main.corr(),annot=True)
plt.title('Correlation between features', fontsize=25)
plt.savefig("../visuals/correlation_matrix.png")
plt.show()

# %%
# draw boxplots to visualize outliers

plt.figure(figsize=(18,15))

plt.subplot(3, 3, 1)
fig = df_main.boxplot(column='mean_int_pf')
fig.set_title('')
fig.set_ylabel('mean_int_pf')

plt.subplot(3, 3, 2)
fig = df_main.boxplot(column='std_pf')
fig.set_title('')
fig.set_ylabel('std_pf')

plt.subplot(3, 3, 3)
fig = df_main.boxplot(column='ex_kurt_pf')
fig.set_title('')
fig.set_ylabel('ex_kurt_pf')

plt.subplot(3, 3, 4)
fig = df_main.boxplot(column='skew_pf')
fig.set_title('')
fig.set_ylabel('skew_pf')

plt.subplot(3, 3, 5)
fig = df_main.boxplot(column='mean_dm')
fig.set_title('')
fig.set_ylabel('mean_dm')

plt.subplot(3, 3, 6)
fig = df_main.boxplot(column='std_dm')
fig.set_title('')
fig.set_ylabel('std_dm')

plt.subplot(3, 3, 7)
fig = df_main.boxplot(column='kurt_dm')
fig.set_title('')
fig.set_ylabel('kurt_dm')

plt.subplot(3, 3, 8)
fig = df_main.boxplot(column='skew_dm')
fig.set_title('')
fig.set_ylabel('skew_dm')

plt.show()
plt.savefig('../visuals/boxplots.png')

# %%
sns.pairplot(df_main, hue='label')
plt.show()

# %%
df_main.columns.tolist()
# Out:
# ['mean_int_pf',
#  'std_pf',
#  'ex_kurt_pf',
#  'skew_pf',
#  'mean_dm',
#  'std_dm',
#  'kurt_dm',
#  'skew_dm',
#  'label']

# %% [markdown]
# #### Skewness value
# mean_int_pf : -1.3750723905207278
# std_pf : 0.1266304634037971
# ex_kurt_pf : 3.6381047281725745
# skew_pf : 5.180859198774812
# mean_dm : 3.6829934238565114
# std_dm : 1.894095372422393
# kurt_dm : 0.4414638629012641
# skew_dm : 2.734284379273907

# %%
## Finding outliers in features
## skew_pf
IQR = df_main.ex_kurt_pf.quantile(0.75) - df_main.ex_kurt_pf.quantile(0.25)
Lower_fence = df_main.ex_kurt_pf.quantile(0.25) - (IQR * 3)
Upper_fence = df_main.ex_kurt_pf.quantile(0.75) + (IQR * 3)
print('ex_kurt_pf outliers are values < {lowerboundary} or > {upperboundary}'.format(lowerboundary=Lower_fence, upperboundary=Upper_fence))
# Out:
# ex_kurt_pf outliers are values < -1.3115830675 or > 1.81200637

# %%
## skew_pf
IQR = df_main.skew_pf.quantile(0.75) - df_main.skew_pf.quantile(0.25)
Lower_fence = df_main.skew_pf.quantile(0.25) - (IQR * 3)
Upper_fence = df_main.skew_pf.quantile(0.75) + (IQR * 3)
print('skew_pf outliers are values < {lowerboundary} or > {upperboundary}'.format(lowerboundary=Lower_fence, upperboundary=Upper_fence))
# Out:
# skew_pf outliers are values < -3.5376358885 or > 4.2768473265

# %%
## mean_dm 
IQR = df_main.mean_dm.quantile(0.75) - df_main.mean_dm.quantile(0.25)
Lower_fence = df_main.mean_dm.quantile(0.25) - (IQR * 3)
Upper_fence = df_main.mean_dm.quantile(0.75) + (IQR * 3)
print('mean_dm outliers are values < {lowerboundary} or > {upperboundary}'.format(lowerboundary=Lower_fence, upperboundary=Upper_fence))
# Out:
# mean_dm outliers are values < -8.70045986625 or > 16.087792642

# %%
## std_dm 
IQR = df_main.std_dm.quantile(0.75) - df_main.std_dm.quantile(0.25)
Lower_fence = df_main.std_dm.quantile(0.25) - (IQR * 3)
Upper_fence = df_main.std_dm.quantile(0.75) + (IQR * 3)
print('std_dm outliers are values < {lowerboundary} or > {upperboundary}'.format(lowerboundary=Lower_fence, upperboundary=Upper_fence))
# Out:
# std_dm outliers are values < -27.534986574999998 or > 70.40042249999999

# %%
## skew_dm 
IQR = df_main.skew_dm.quantile(0.75) - df_main.skew_dm.quantile(0.25)
Lower_fence = df_main.skew_dm.quantile(0.25) - (IQR * 3)
Upper_fence = df_main.skew_dm.quantile(0.75) + (IQR * 3)
print('skew_dm outliers are values < {lowerboundary} or > {upperboundary}'.format(lowerboundary=Lower_fence, upperboundary=Upper_fence))
# Out:
# skew_dm outliers are values < -278.08597375 or > 452.3558086875

# %%
## mean_int_pf 
IQR = df_main.mean_int_pf.quantile(0.75) - df_main.mean_int_pf.quantile(0.25)
Lower_fence = df_main.mean_int_pf.quantile(0.25) - (IQR * 3)
Upper_fence = df_main.mean_int_pf.quantile(0.75) + (IQR * 3)
print('mean_int_pf outliers are values < {lowerboundary} or > {upperboundary}'.format(lowerboundary=Lower_fence, upperboundary=Upper_fence))
# Out:
# mean_int_pf outliers are values < 22.4609375 or > 205.5546875

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Features - Target realationship

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.mean_int_pf, df_main.label, marker='+', color='red')
plt.xlabel('mean_int_pf')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.std_pf, df_main.label, marker='+', color='red')
plt.xlabel('std_pf')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.ex_kurt_pf, df_main.label, marker='+', color='red')
plt.xlabel('ex_kurt_pf')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.skew_pf, df_main.label, marker='+', color='red')
plt.xlabel('skew_pf')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.mean_dm, df_main.label, marker='+', color='red')
plt.xlabel('mean_dm')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.std_dm, df_main.label, marker='+', color='red')
plt.xlabel('std_dm')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.kurt_dm, df_main.label, marker='+', color='red')
plt.xlabel('kurt_dm')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_main.skew_dm, df_main.label, marker='+', color='red')
plt.xlabel('skew_dm')
plt.show()
